# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
keyword = "diagnostic device"
num_articles = 100
encodingmethod = "utf-8"
errortype = "strict"

# %%
import urllib.parse
import urllib.request
import xml.etree.ElementTree as ET

encoded_search_term = urllib.parse.quote(keyword, encoding=encodingmethod, errors=errortype)
url = f'http://export.arxiv.org/api/query?search_query=all:{encoded_search_term}&start=0&max_results={num_articles}'

print(f"Searching for '{keyword}' on arXiv...")
print(f"URL: {url}")

try:
    response = urllib.request.urlopen(url)
    try:
        url_read = response.read().decode("utf-8")
    except UnicodeDecodeError:
        response = urllib.request.urlopen(url)
        url_read = response.read().decode("utf-8", errors="ignore")

    parse_xml = ET.fromstring(url_read)
    print("Successfully retrieved search results!")
except Exception as e:
    print(f"Error retrieving data: {e}")
    raise
# Out:
# Searching for 'diagnostic device' on arXiv...
# URL: http://export.arxiv.org/api/query?search_query=all:diagnostic%20device&start=0&max_results=100
# Successfully retrieved search results!

# %%
ns = {"ns": "http://www.w3.org/2005/Atom"}
entries = parse_xml.findall('ns:entry', ns)

articles_data = []
for entry in entries:
    link = entry.find('ns:link[@type="application/pdf"]', ns)
    if link is not None and "href" in link.attrib:
        pdf_url = link.attrib['href']

        title = entry.find('ns:title', ns)
        title_text = title.text.strip() if title is not None else "Unknown Title"

        authors = entry.findall('ns:author/ns:name', ns)
        author_names = [author.text for author in authors] if authors else ["Unknown Author"]

        published = entry.find('ns:published', ns)
        published_date = published.text[:10] if published is not None else "Unknown Date"

        summary = entry.find('ns:summary', ns)
        summary_text = summary.text.strip() if summary is not None else "No summary available"

        metadata = {
            'title': title_text,
            'authors': author_names,
            'published': published_date,
            'summary': summary_text
        }

        articles_data.append({
            'pdf_url': pdf_url,
            'metadata': metadata
        })

print(f"Found {len(articles_data)} articles with PDF links")
for i, article in enumerate(articles_data):
    print(f"{i+1}. {article['metadata']['title'][:80]}...")
# Out:
# Found 100 articles with PDF links
# 1. An Electrochemical Potentiostat Interface for Mobile Devices: Enabling
#   Remote ...
# 2. Practical Statistical Considerations for the Clinical Validation of
#   AI/ML-enab...
# 3. Cross-device Federated Learning for Mobile Health Diagnostics: A First
#   Study o...
# 4. Random Forests for Industrial Device Functioning Diagnostics Using
#   Wireless Se...
# 5. D-Mag: a laboratory for studying plasma physics and diagnostics in
#   strong magn...
# 6. Noninvasive Acute Compartment Syndrome Diagnosis Using Random Forest
#   Machine L...
# 7. Diagnostic criterion for crystallized beams...
# 8. Plasma diagnostics using digital holographic interferometry...
# 9. Bioimpedance a Diagnostic Tool for Tobacco Induced Oral Lesions: a Mixed
#   Model...
# 10. Active Sampling for MRI-based Sequential Decision Making...
# 11. Conceptual Study of a Collective Thomson Scattering Diagnostic for SPARC...
# 12. Integrated Data Analysis and Validation...
# 13. Special behavior of alkali beam emission spectroscopy in
#   low-ion-temperature p...
# 14. Design considerations for an ultrahigh-bandwidth Phase 6 Contrast
#   Imaging syst...
# 15. Predicting proximity with ambient mobile sensors for non-invasive health
#   diagn...
# 16. On-line Remote EKG as a Web Service...
# 17. Thomson backscattering diagnostics of nanosecond electron bunches in
#   high spac...
# 18. A likelihood based sensitivity analysis for publication bias on summary
#   ROC in...
# 19. A new technique for tokamak edge density measurement based on microwave
#   interf...
# 20. Cybersecurity and Frequent Cyber Attacks on IoT Devices in Healthcare:
#   Issues ...
# 21. SNS Front End Diagnostics...
# 22. Field Effect Transistor Nanosensor for Breast Cancer Diagnostics...
# 23. Conceptual design of electron beam diagnostics for high brightness
#   plasma acce...
# 24. Deep Learning for Plasma Tomography and Disruption Prediction from
#   Bolometer D...
# 25. Inside Job: Diagnosing Bluetooth Lower Layers Using Off-the-Shelf
#   Devices...
# 26. Large Language Models in Ambulatory Devices for Home Health Diagnostics:
#   A cas...
# 27. Advances in Biomedical Devices_A comprehensive Exploration of
#   Cardiovascular a...
# 28. Machine-Learning-Powered Neural Interfaces for Smart Prosthetics and
#   Diagnosti...
# 29. Role of Edge Device and Cloud Machine Learning in Point-of-Care
#   Solutions Usin...
# 30. Resolving Two Beams in Beam Splitters with a Beam Position Monitor...
# 31. Vibration diagnostics instrumentation for ILC...
# 32. Surface plasmon based thermo-optic and temperature sensor for
#   microfluidic the...
# 33. A contactless microwave-based diagnostic tool for high repetition rate
#   laser s...
# 34. Faithful hierarchy of genuine $n$-photon quantum non-Gaussian light...
# 35. A multiple testing framework for diagnostic accuracy studies with
#   co-primary e...
# 36. An Integrated AI-Enabled System Using One Class Twin Cross Learning
#   (OCT-X) fo...
# 37. Can User-Level Probing Detect and Diagnose Common Home-WLAN Pathologies?...
# 38. Whole Device Modeling of the FuZE Sheared-Flow-Stabilized Z Pinch...
# 39. Model Compression Engine for Wearable Devices Skin Cancer Diagnosis...
# 40. Designing a Deep Learning-Driven Resource-Efficient Diagnostic System
#   for Meta...
# 41. Qubit assignment using time reversal...
# 42. Beyond One-Time Validation: A Framework for Adaptive Validation of
#   Prognostic ...
# 43. Multiplexed Biosensing of Proteins and Virions with Disposable Plasmonic
#   Assay...
# 44. Systems-Theoretic and Data-Driven Security Analysis in ML-enabled
#   Medical Devi...
# 45. Image-guided therapy system for interstitial gynecologic brachytherapy
#   in a mu...
# 46. Measuring national capability over big sciences multidisciplinarity: A
#   case st...
# 47. Rapid, remote and low-cost finger vasculature mapping for heart rate
#   monitorin...
# 48. Beyond the Nucleus: Cytoplasmic Dominance in Follicular Thyroid
#   Carcinoma Dete...
# 49. DrHouse: An LLM-empowered Diagnostic Reasoning System through Harnessing
#   Outco...
# 50. Diagnostic Systems in the Muon $g-2$ experiment at Fermilab...
# 51. Application of digital regulated Power Supplies for Magnet Control at
#   the Swis...
# 52. Feasibility of Diagnostics Undulator Studies at ASTA...
# 53. Using complex networks towards information retrieval and diagnostics in
#   multid...
# 54. Experimental diagnostics of entanglement swapping by a collective
#   entanglement...
# 55. Two-dimensional time- and space-resolved diagnostic method for
#   integrated impl...
# 56. Deep convolutional neural networks for multi-scale time-series
#   classification ...
# 57. Multi-Channel Masked Autoencoder and Comprehensive Evaluations for
#   Reconstruct...
# 58. Time-Correlated Single-Photon Counting for versatile longitudinal
#   diagnostics ...
# 59. A Multimodal In Vitro Diagnostic Method for Parkinson's Disease
#   Combining Faci...
# 60. Fast particle-driven ion cyclotron emission (ICE) in tokamak plasmas and
#   the c...
# 61. Radiation effects on the Gaia CCDs after 30 months at L2...
# 62. Diagnostic Quality Assessment of Fundus Photographs: Hierarchical Deep
#   Learnin...
# 63. Am I Infected? Lessons from Operating a Large-Scale IoT Security
#   Diagnostic Se...
# 64. Guaranteed violation of a Bell inequality without aligned reference
#   frames or ...
# 65. Nanostructured graphene for spintronics...
# 66. Towards a Magnetically Actuated Laser Scanner for Endoscopic
#   Microsurgeries...
# 67. A Secure Proxy-based Access Control Scheme for Implantable Medical
#   Devices...
# 68. The Raspberry Pi Auto-aligner: Machine Learning for Automated Alignment
#   of Las...
# 69. Training and Profiling a Pediatric Emotion Recognition Classifier on
#   Mobile De...
# 70. On Medical Device Cybersecurity Compliance in EU...
# 71. Femtosecond electron beam probe of ultrafast electronics...
# 72. Single Langmuir Probe Diagnostics Device...
# 73. Low-Cost Device Prototype for Automatic Medical Diagnosis Using Deep
#   Learning ...
# 74. Diagnostic reasoning with A-Prolog...
# 75. Measurement and Modeling of Electron Cloud in a Field Free Environment
#   Using R...
# 76. Spectral analysis for noise diagnostics and filter-based digital error
#   mitigat...
# 77. Fusion research in a Deuterium-Tritium tokamak...
# 78. Simultaneous 12-Lead Electrocardiogram Synthesis using a Single-Lead ECG
#   Signa...
# 79. Status of COLDDIAG: A Cold Vacuum Chamber for Diagnostics...
# 80. A portable X-pinch design for x-ray diagnostics of warm dense matter...
# 81. Improving Clinical Diagnosis Performance with Automated X-ray Scan
#   Quality Enh...
# 82. Photocurrent as a multi-physics diagnostic of quantum materials...
# 83. Zodiac: A Cardiologist-Level LLM Framework for Multi-Agent Diagnostics...
# 84. Detecting Long QT Syndrome and First-Degree Atrioventricular Block using
#   Singl...
# 85. The environment effect on operation of in-vessel mirrors for plasma
#   diagnostic...
# 86. Intelligent Automated Diagnosis of Client Device Bottlenecks in Private
#   Clouds...
# 87. Signal focusing through active transport...
# 88. Low complexity convolutional neural network for vessel segmentation in
#   portabl...
# 89. Thomson scattering on the Large Plasma Device...
# 90. Elasticity Measurements of Expanded Foams using a Collaborative Robotic
#   Arm...
# 91. Efficient Detection of Strong-To-Weak Spontaneous Symmetry Breaking via
#   the Ré...
# 92. BATIS: Bootstrapping, Autonomous Testing, and Initialization System for
#   Quantu...
# 93. A Deep Neural Network Deployment Based on Resistive Memory Accelerator
#   Simulat...
# 94. Broadband Angular-selective Mid-infrared Photodetector...
# 95. Neutron diagnostics for the physics of a high-field, compact, $Q\geq1$
#   tokamak...
# 96. Time-domain global similarity method for automatic data cleaning for
#   multi-cha...
# 97. Applications of Deep Learning to Nuclear Fusion Research...
# 98. Efficient and powerful equivalency test on combined mean and variance
#   with app...
# 99. Simulated assessment of light transport through ischaemic skin flaps...
# 100. Multiscale fabrication of scalable biomimetic 3-D, integrated
#   micro-nanochanne...

# %%
from sentence_transformers import SentenceTransformer
import faiss

dimension = 768
model = SentenceTransformer('pritamdeka/S-BioBert-snli-multinli-stsb')
chunk_index = faiss.IndexFlatL2(dimension)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/610 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/433M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/546 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
import numpy as np
def cos_sim(e1, e2):
    return np.dot(e1, e2) / (np.linalg.norm(e1) * np.linalg.norm(e2))

# %%
import requests
from PyPDF2 import PdfReader
import io
import nltk

chunks = []
chunk_size_sentences = 50

for i, article in enumerate(articles_data):
    try:
        pdf_response = requests.get(article['pdf_url'], timeout=30)
        pdf_response.raise_for_status()

        pdf_file = io.BytesIO(pdf_response.content)
        pdf_reader = PdfReader(pdf_file)
        pdf_text = ""

        for page in pdf_reader.pages:
            page_text = page.extract_text()
            if page_text and page_text.strip():
                pdf_text += page_text + " "

        pdf_text = re.sub(r' {2,}', ' ', pdf_text)
        pdf_text = re.sub(r'\n{3,}', '\n\n', pdf_text)
        pdf_text = re.sub(r'[\f\v\r]', ' ', pdf_text)
        pdf_text = re.sub(r'[\x00-\x08\x0B\x0C\x0E-\x1F\x7F]', '', pdf_text)
        pdf_text = re.sub(r'([.!?])\s*([A-Z])', r'\1 \2', pdf_text)
        pdf_text = pdf_text.strip()

        sentences = nltk.sent_tokenize(pdf_text)
        num_sentences = len(sentences)

        for j in range(0, num_sentences, chunk_size_sentences):
            chunk_sentences = sentences[j:j + chunk_size_sentences]
            chunk_text = " ".join(chunk_sentences)

            if chunk_text:
                chunk_embedding = model.encode(chunk_text, convert_to_tensor=True)
                chunk_embedding = chunk_embedding.cpu().numpy().astype('float32')

                chunk_data = {
                    'text': chunk_text,
                    'embedding': chunk_embedding,
                    'metadata': article['metadata'],
                    'sentence_count': len(chunk_sentences)
                }
                chunks.append(chunk_data)

    except Exception as e:
        print(f"Error processing article {i+1}: {str(e)}")
# Out:
# /usr/local/lib/python3.11/dist-packages/PyPDF2/_cmap.py:142: PdfReadWarning: Advanced encoding /SymbolSetEncoding not implemented yet
#   warnings.warn(

# %%
for chunk in chunks:
    chunk_index.add(chunk['embedding'].reshape(1, -1))

# %%
chunks[0]
# Out:
# {'text': '1 \n An Electrochemical Potentiostat Interface for Mobile Devices : Enabling \nRemote Medical Diagnostics \nHenry Fu, Henry Chow, Michael Lew, Shruti Menon, Craig Scratchley, M. Ash Parameswaran \nAbstract \nAn electrochemical potentiostat interface for mobile devices has been designed and \nimplemented. The interface consists of a potentiostat module, a microcontroller module , and a \nBluetooth module. The potentiostat module performs electrochemical measurements and detects \nthe response s from the samples. The microcontro ller module controls the test and \ncommunication processes. The Bluetooth module links the system to a mobile device, where the \nmobile device acts as a control -console, data storage system , communication unit , and graphica l \nplotter for the overall diagnosti c processes. This interface is suitable for point -of-care and remote \ndiagnostics , enhanc ing the capabilities of mobile devices in telemedicine. Keywords \nMobile device; Remote medical diagnostics; Potentiostat, Bluetooth; Cyclic v oltammetry ; \nElectrochemical detection \n1. Introduction \nIntelligent, p ortable electronic systems can assist healthcare professionals to efficiently perform \nmedical diagnostics [1-4]. This is particularly important in remote areas and developing \ncountries, where the lack of local medical facilities and personnel could delay diagnos is and \ntreatment . Timely diagnosis is critical especially when dealing with newborn infants, whereas a \ndelay may lead to an increase in the severity of condition or even cause death. To address thi s \nissue, there is a growing interest to develop r emote and ons ite diagnostic technologies and \ninstruments. Ideally, operation of the remo te diagnostic equipment should require minimal or no \ntraining . An intuitive user interface should allow the user to perform diagnostics easily using the \nmobile device. This approach opens up the possibility to incorporate intelligent algorithms in the \nmobile device for an automated diagnostic advisory as well as the ability to upload the test -data, \nthrough a telecommunication link, to a central location where a professional can examine the \nresults and offer diagnostic consultancy and treatment plan. High -resolution displays, touch -screen input, Bluetooth and WiFi co nnectivity, USB ports, GPS, \nand many other sensors are becoming ubiquitous even in simple mobile devices. Integration of a \ndiagnostic system using these mobile devices generates new implementation possibilities \nrevolutionizing the power of telemedicine. 2 \n 2. Potentiostat Interface \nElectrochemistry is one of the powerful emerging analytical tools in medical diagnostics [5-7]. Literature shows electrochemical tests for diagnosing cancer [5], cardiovascular diseases [6] and \nantibiotic susceptibility [7]. Typically, an electrochemical test requires an electronic -circuit \ncalled a potentiostat. A potentiostat is an electronic device that is connected to a 3 -electrode -unit \n(sensor) which is immersed in a biochemical (body -fluid) sample . The potentiostat applies a \nvoltage and records the current response that is characteristic of the sample being tested. This \nrespo nse is used in diagnostics . Integration of the potentiostat to a mobile device makes the \ndiagnostic unit portable. To interface the potentiostat to a mobile device, a communic ation link is \nrequired . Bluetooth was chosen for this purpose as it features both low power and wireless \ncommunication . The latter allows the mobile platform to be isolated from the test sample. Additionally, Bluetooth modules are small in size and are ideally suited for portable systems. The potentiostat interface include s a microcontroller for managing the functionality . To ensure \nportability the potentiostat interface should be compact and consume minimal electrical power. The WiFi or cellular module of mobile devices can be used to transfer the test -results to medical \nprofessio ...
#  'embedding': array([ 2.80300707e-01,  3.62314999e-01,  1.31872281e-01,  3.86761606e-01,
#         -7.90630654e-02,  3.09369713e-03, -7.35620320e-01,  3.73020992e-02,
#         -2.04159111e-01, -3.43812913e-01,  5.35298474e-02,  2.26303101e-01,
#         -1.84886470e-01, -3.09939571e-02, -4.35313046e-01, -1.86178461e-01,
#         -1.31248221e-01,  5.72259426e-01,  6.17164433e-01,  1.99991122e-01,
#         -4.98098820e-01, -2.98603684e-01, -5.22168279e-01, -7.03019083e-01,
#          2.50830829e-01, -5.11464119e-01,  5.36150336e-01, -6.29080653e-01,
#          5.13461173e-01, -1.93824008e-01, -8.68368149e-01,  4.45804447e-01,
#         -3.36879432e-01,  1.15813971e-01, -1.00659415e-01,  1.19231060e-01,
#         -1.03894070e-01,  4.55115348e-01, -2.52004296e-01,  2.15773925e-01,
#         -2.03234464e-01,  3.20076905e-02,  1.22008868e-01, -1.89461052e-01,
#         -5.19864380e-01,  4.09125024e-03, -3.11398637e-02, -2.90906783e-02,
#         -1.26033604e-01,  3.06434959e-01,  8.19842815e-02, -4.07274693e-01,
#         -4.64046776e-01, -1.53231815e-01,  9.75567196e-03, -1.33085042e-01,
#          2.67728359e-01,  4.59647119e-01,  1.25178337e-01, -3.02592218e-02,
#         -4.88016665e-01, -4.42036092e-01,  3.82601358e-02,  2.89655238e-01,
#         -1.90286398e-01, -3.90800506e-01,  1.18989170e-01, -1.99046448e-01,
#         -7.23002434e-01, -2.20491998e-02, -8.40968013e-01, -8.54584932e-01,
#          5.24966240e-01, -5.31005040e-02,  4.33096558e-01, -5.53361535e-01,
#          1.87827632e-01,  3.38235676e-01,  4.08935696e-02,  9.62340236e-02,
#         -1.73954725e-01, -1.18773170e-01, -1.73367307e-01, -3.57624114e-01,
#         -1.86948299e-01, -1.82219982e-01,  1.19790599e-01,  5.93805492e-01,
#         -2.18550086e-01, -1.20880544e-01, -4.24147576e-01, -4.05194432e-01,
#          3.73944603e-02, -1.01205409e+00,  4.71659638e-02, -3.07567924e-01,
#          1.47346407e-01,  4.57550511e-02, -2.90942550e-01,  3.70727539e-01,
#          4.27762896e-01,  2.57935703e-01,  4.63631809e-01, -5.47383964e-01,
#         -5.22144139e-01, -3.71345639e-01,  5.79042971e-01,  2.77191430e-01,
#          1.57710556e-02, -2.28360415e-01,  3.19259048e-01, -1.26212519e-02,
#          3.10378909e-01,  2.30771452e-01,  2.32153878e-01,  4.13330168e-01,
#         -3.88119817e-01,  3.21655542e-01,  3.22233774e-02, -4.36064214e-01,
#         -1.72840685e-01, -1.73065484e-01,  1.30593002e-01,  6.36448860e-01,
#         -2.64037877e-01, -1.35701403e-01, -8.36682394e-02, -1.57494351e-01,
#         -2.41245344e-01, -4.14824009e-01, -4.24927533e-01, -5.49957275e-01,
#         -2.98584938e-01,  2.03682080e-01,  4.65086758e-01,  4.03093934e-01,
#         -8.76947761e-01,  2.88194865e-01, -5.38144886e-01, -4.62138116e-01,
#          3.08262020e-01,  2.78594971e-01,  3.64072263e-01, -1.84941411e-01,
#         -2.79167425e-02,  2.49596298e-01,  1.59467161e-01,  6.35401249e-01,
#          4.78633285e-01,  3.50224912e-01,  5.69988906e-01, -2.29259536e-01,
#          1.44977095e-02, -2.25366592e-01, -2.44686633e-01,  2.98615783e-01,
#          2.18137786e-01, -1.64244205e-01, -4.84598905e-01,  4.25244093e-01,
#          7.12557971e-01, -3.69362742e-01, -1.94174767e-01,  6.88403174e-02,
#         -9.60714743e-02, -4.30017710e-01,  5.74841917e-01, -6.44162714e-01,
#         -1.62650228e-01, -5.83851188e-02,  5.59021160e-03,  4.54987526e-01,
#          6.39105797e-01,  2.54144073e-01,  7.91166723e-02, -2.74890453e-01,
#          4.30493563e-01,  1.31056264e-01, -3.52858931e-01,  7.87978411e-01],
#        dtype=float32),
#  'metadata': {'title': 'An Electrochemical Potentiostat Interface for Mobile Devices: Enabling\n  Remote Medical Diagnostics',
#   'authors': ['Henry Fu',
#    'Henry Chow',
#    'Michael Lew',
#    'Shruti Menon',
#    'Craig Scratchley',
#    'M. Ash Parameswaran'],
#   'published': '2015-09-29',
#   'summary': 'An electrochemical potentiostat interface for mobile devices has been\ndesigned and implemented. The interface consists of a potentiostat module, a\nmicrocontroller module, and a Bluetooth module. The potentiostat module\nperforms electrochemical measurements and detects the responses from the\nsamples. The microcontroller module controls the test and communication\nprocesses. The Bluetooth module links the system to a mobile device, where the\nmobile device acts as a control-console, data storage system, communication\nunit, and graphical plotter for the overall diagnostic processes. This\ninterface is suitable for point-of-care and remote diagnostics, enhancing the\ncapabilities of mobile devices in telemedicine.'},
#  'sentence_count': 50}

# %%
index_filename = "chunks.index"

faiss.write_index(chunk_index, index_filename)

print(f"FAISS index exported to {index_filename}")
# Out:
# FAISS index exported to chunks.index
